# %% [markdown]
# # Homework 8 - Machine Learning IV

# %% [markdown]
# ## Deadline: November 16th, at noon (12:00)

# %% [markdown]
# #### About this homework
#
# In this homework, we will try Tensorlow playground, read an article and compete in Kaggle. Before solving these tasks, please make sure that you have looked through the slides of Lecture 09.
#
#
# #### General instructions
#
# Please look up the general instructions about homeworks in the first homework.
#
# #### Tracking your time
#
# We will appreciate if you track your time spent on solving the homework and report it in the dedicated cells at the end of the homework. This is not compulsory and does not affect your grade in any way. The collected information will be used to improve future homeworks.

# %% [markdown]
# # Task 1. Tensorflow playground (1 points)

# %% [markdown]
# Attempt solving the spiral problem (bottom right dataset among the 4 provided datasets) in the [TensorFlow playground](http://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.32922&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false) with the smallest possible number of neurons and layers. Please use the default training to test ratio, noise and batch size parameters. However, you can try different activation functions, learning rate, regularizations etc. <b>Please consider the task solved if the test loss as shown at the top right of the website is below 0.05</b> and if there are no points of some class on the area of another colour, meaning that all training points are correctly classified.

# %% [markdown]
# **a. Describe your search process in finding the architecture (a combination of neurons and layers) which solves the problem. Did you try different architectures randomly or systematically? Which changes did you try to make to the architecture?**

# %% [markdown]
# **<font color='red'>Answer:</font>** This is my process :
# - First i try to add an other hidden layers but not working
# - then, by adding X12 and X22 i was very close to the 0.05 but to noisy. Also, some points were misclassified. I reach the "validation" once but it was very lucky so no validation
# - i was thinking that by adding X1X2 it will be better but the data were a lot missclassified
# - then, i tried with X1,X2,X12 and X22 and also with 3 hidden layer with 2 neurons but it was a lot worse
# - a better result with the third hidden layer with 4 neurons
# - i try to restart from the beginning, with just X1,X2 and X1X2 and 2 HL but no results
#
# **<font color='purple'>
# So back to the time it was working the best, with X1,X2,X12,X22 with 2 HL but with 6 and 4 neurons. This time, it worked !</font>**
# - i tried the same with 5 neurons but not working at all.

# %% [markdown]
# **b. Make a screenshot that would show that your network has solved the problem. Please report what epoch your network has reached and train and test loss it has achieved. Additionally, report the total number of different architectures that you tried until reaching the desired result.**

# %%
from IPython.display import Image
Image(filename='screenshot.png') # please uncomment this line and replace 'screenshot.png' by the correct filename

# %% [markdown]
# **<font color='red'>Epoch:</font>** 1.000

# %% [markdown]
# **<font color='red'>Train loss:</font>** 0.005

# %% [markdown]
# **<font color='red'>Test loss:</font>** 0.013

# %% [markdown]
# **<font color='red'>Number of architectures tried:</font>** 8

# %% [markdown]
# Read the supporting text below the demo in the tensorflow playground webpage and answer the following questions.

# %% [markdown]
# **c. What do the colours orange and blue stand for in:**<br>

# %% [markdown]
# **<font color='red'>1. Connections between neurons:</font>** "The line are colored by the weights of the connections between neurons", means that the colour of the line shows us what neuron is used to carry which information by the network.

# %% [markdown]
# **<font color='red'>2. Inside neurons:</font>** We see different shape inside a neuron, and each shape show us how a neuron see the data with all the information he gets. By additionning all the neurons, we have this complex representation.

# %% [markdown]
# **<font color='red'>3. Inside the output image (the one with a spiral):</font>** Inside the output image, the dots are colored "depending on their original values". We can compare if a dot is well predict thanks to the background color who shows what the network is predicting.

# %% [markdown]
# **d. Which input features have you chosen for your architecture? Why are they important for your network to solve the problem?**

# %% [markdown]
# **<font color='red'>Answer:</font>** I choosed X1, X2, X12 and X22 :
# - X1 and X2 in order to have a base for the representation
# - X12 and X22 so be able to have some details and reproduce the shape of spiral.

# %% [markdown]
# **e. If you have changed any other hyper-parameters such as the learning rate, activation function, regularization or regularization rate, then please explain the reasons and implications of this change.**

# %% [markdown]
# **<font color='red'>Answer:</font>** We have :
# - with a learning rate of 0.01, the same result but with more epochs (learn the same but with more time)
# - with a learning rate of 10, a complete not working network because it can be predict correclty any points
# - with ReLu, a network that works pretty well especially with complex shape
# - with L1 or L2 regularization, a noisy but functionnal network  (too much hesitation)
# - with a regularization rate at 1, a network who is slow and not functionnal, because there is too much "regularization" in the data predicted
#
# We can test with everything, but we can adjust with all these parameters what we want to do (precise network but slow, fast network, ...)

# %% [markdown]
# # Task 2. Publication review (1 points)

# %% [markdown]
# Read the article by Domingos: A few useful things to know about machine learning (communications of the ACM, Vol. 55 No. 10, Pages 78-87 doi: 10.1145/2347736.2347755 via ACM Digital library, here as [PDF](https://courses.cs.ut.ee/MTAT.03.183/2017_fall/uploads/Main/domingos.pdf).

# %% [markdown]
# **a. Make a numbered list of 7 key messages with a supporting 1-2 sentence example or clarification of that message. Please choose the messages so that:**
#
# * each key message is from different page (please indicate the page number with the messages)
# * at least 3 of your chosen messages should be such that they have not been covered in our lectures, please indicate which ones.

# %% [markdown]
# **<font color='red'>1.</font>** [PAGE 1] Machine learning is used in more and more applications nowadays, and this trend grows really fast.

# %% [markdown]
# **<font color='red'>2.</font>** [PAGE 3] It is more than important to test the classifier on new data, and not on trained data.

# %% [markdown]
# **<font color='red'>3.</font>** [PAGE 4] Overfitting is when 'knowledge and data we have are not sufficient to completely determine the correct classifier', and can be solve with cross-validation or regularization.

# %% [markdown]
# **<font color='red'>4.</font>** [PAGE 5] Lot of algorithm works well in low dimension, but failed in high dimension.

# %% [markdown]
# **<font color='red'>5.</font>** [NEW] [PAGE 7]  Some features who look irrelevant alone can be useful is they are used in combination.

# %% [markdown]
# **<font color='red'>6.</font>** [NEW] [PAGE 8] Even if complex algorithm can be more seductive, they have more knobs you need to have if you want good results. So, it's better to analyse data with first a simple algorithm (naïve Bayes, logic regression, ...)

# %% [markdown]
# **<font color='red'>7.</font>** [NEW] [PAGE 10] It's not because we have a representation of a function than we can easily learned it  : "standard decision tree learners cannot learn trees with more leaves than there are training examples".

# %% [markdown]
# # Task 3. Kaggle Competition (2 points)

# %% [markdown]
# Participate in the Kaggle inClass competition [from here](https://www.kaggle.com/t/bdb1182495fb443bacd606f066b5297c) that we have prepared for our course. [Kaggle](https://www.kaggle.com/) is the most well-known platform for machine learning competitions. Data scientists team up with colleagues to solve various data science-related [challenges](https://www.kaggle.com/competitions). In our competition, there is only one person you can rely on - **<font color='red'>you, yourself</font>**. You are allowed to make maximally 10 submissions per day. Each submission is a CSV-file containing your predicted labels on the test data. You are provided with an example submission file showing how to format the CSV-file, please follow this format or otherwise, your submission will not be graded. Also, you should have all the knowledge and skills from the previous homeworks. Please complete the following objectives:<br>
# * Register for the competition and create a one-person team. **<font color='red'>Please name it -  first name surname (Group nr.) Example: John Smith (Group 6)</font>**
# * To get 1 point you should make **at least 3 submissions** obtained with different learning algorithms. Please give meaningful names to the submissions (like "linear SVM" or "KNN with K=1"). **Kaggle expects class probabilities for each row in the test file and not binary classes. (It is important for getting good AUC scores)**
# * Include a screenshot of your submissions into the report, where it would be clear which submissions are yours.
# * To get another point you should make a submission that reaches or gets higher than AUC=0.92 score. In order to claim this point, describe your best current solution.<br><br>
# Hint 1. To save the result as a file, you can use <code>df.to_csv()</code>

# %%
# TODO - code for your solutions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

train_data = pd.read_csv("traindata.csv")
test_data = pd.read_csv("testdata.csv")

train_data.head()
# Out:
#    id  age         job   marital  education default  balance housing loan  \
# 0   1   44    services  divorced  secondary      no       51     yes  yes
# 1   2   34  management   married   tertiary      no     1036     yes   no
# 2   3   32  management    single    unknown      no     3044     yes   no
# 3   4   36  technician   married  secondary      no     3579      no   no
# 4   5   55      admin.   married  secondary      no     1662      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   unknown   27   may      3094         2     -1         0  unknown  1
# 1  cellular   19   nov        54         7     -1         0  unknown  0
# 2   unknown    2   jun       651         1     -1         0  unknown  0
# 3  cellular   14   aug       308         2     -1         0  unknown  0
# 4  cellular    4   jun        94         2     -1         0  unknown  1

# %%
from sklearn.preprocessing import LabelEncoder
cols = train_data.dtypes[train_data.dtypes == 'O'].index

label = LabelEncoder()
for col in cols:
    train_data[col] = label.fit(train_data[col]).transform(train_data[col])
    test_data[col] = label.fit(test_data[col]).transform(test_data[col])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

train = train_data.drop(['y'],axis = 1)
test = train_data['y']

X_train, X_test, y_train, y_test = train_test_split(train, test, 
                                                      random_state = 1111, 
                                                      test_size = 0.30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-204bd0d6cb7c> in <module>
#       7 test = train_data['y']
#       8
# ----> 9 X_train, X_test, y_train, y_test = train_test_split(train, test,
#      10                                                       random_state = 1111,
#      11                                                       test_size = 0.30)
#
# NameError: name 'train_test_split' is not defined

# %%
svm = SVC()
svm.fit(train,test)
predictions = svm.predict(test_data)

submission = pd.DataFrame({'id':test_data['id'],'y':predictions})
submission.to_csv('SVM Model.csv',index=False)

# %%
knn = KNeighborsClassifier(n_neighbors = 7)
knn.fit(train, test)
predictions = knn.predict(test_data)

submission = pd.DataFrame({'id':test_data['id'],'y':predictions})
submission.to_csv('KNN Model.csv',index=False)

# %%
rfc = RandomForestClassifier()
rfc.fit(train, test)
predictions = rfc.predict(test_data)

submission = pd.DataFrame({'id':test_data['id'],'y':predictions})
submission.to_csv('Random Forest Model.csv',index=False)

# %%
gboost = GradientBoostingClassifier()
gboost.fit(train, test)
y_pred = gboost.predict(test_data)

submission = pd.DataFrame({'id':test_data['id'],'y':predictions})
submission.to_csv('GradientBoostingClassifier.csv',index=False)

# %% [markdown]
# **<font color='red'>Describe your approach:</font>** My approach is to test easy and know method as :
# - SVM
# - KNN
# - RandomForestClassifier
# - GradientBoostingClassifier

# %%
Image(filename='kagle.png') # please uncomment this line and replace 'screenshot.png' by the correct filename
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2269487928bb> in <module>
# ----> 1 Image(filename='kagle.png') # please uncomment this line and replace 'screenshot.png' by the correct filename
#
# NameError: name 'Image' is not defined

# %% [markdown]
# **<font color='red'>Best solution description:</font>** I didn't reach the 0.92 .. but i tried but not enough !

# %% [markdown]
# # Bonus Task 1. (up to 2 points)

# %% [markdown]
# As usually done in Kaggle competitions, we have split the test data into a public and a private fold. The test data is also available on the Kaggle page, but you do not know which test instance is in public and which in the private. Until the deadline, you will see only the results on the public test fold. **So, do not overfit to public test dataset!** Before the deadline, you should select up to 2 submissions for judging. The final leaderboard will be made based on the predictions on the private test fold. <br>
# 1. Finish in the top 5 of the private leaderboard in Kaggle inClass to get 2 bonus points. <br>
# 2. Finish in the places 6-20 of the private leaderboard in Kaggle inClass to earn 1 bonus point.

# %% [markdown]
# ## <font color='red'>This was the last task! Please restart the kernel and run all before submission! (`Kernel -> Restart and Run All`)</font>

# %% [markdown]
# ## Comments (voluntary):
#
# Write comments about the homework here. For example, comment if You had difficulties with some exercises or you wish there were some other topics covered in the homework. In addition, comment if you found some task interesting or fascinating.

# %% [markdown]
# **<font color='red'>Comments:</font>** Write here.

# %% [markdown]
# ## How long did it take you to solve the homework?

# %% [markdown]
# Please answer as precisely as you can. It does not affect your points or grade in any way. It is okey, if it took 0.5 hours or 24 hours. Please count in astronomical hours (1 hour = 60 minutes) and not academic hours (1 hour = 45 minutes). The collected information will be used to improve future homeworks.
# <font color = "red"><b> Please replace "X" with the amount of hours and don't change the unit "hours" or write any other text. </b></font>

# %% [markdown]
# **<font color='red'>Task 1 (please change X in the next cell into your estimate)</font>**

# %% [markdown]
# X hours

# %% [markdown]
# **<font color='red'>Task 2 (please change X in the next cell into your estimate)</font>**

# %% [markdown]
# X hours

# %% [markdown]
# **<font color='red'>Task 3 (please change X in the next cell into your estimate)</font>**

# %% [markdown]
# X hours

# %% [markdown]
# **<font color='red'>Task B1 (please change X in the next cell into your estimate)</font>**

# %% [markdown]
# X hours

# %% [markdown]
# **<font color='red'>TOTAL (please change X in the next cell into your estimate)</font>**

# %% [markdown]
# X hours

# %% [markdown]
# **<font color='red'>THANK YOU FOR YOUR EFFORT!</font>**
